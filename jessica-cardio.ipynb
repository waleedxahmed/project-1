# %%
#dependencies
import pandas as pd
import math 
import time
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
import csv

# %%
#file
health_data_to_load = "cardio_train.csv"

#read & store
cardio_data = pd.read_csv(health_data_to_load)

cardio_data.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
# 'floor' returns largest integer less than or equal to x. 'ceiling' returns smallest integer. >== x
#convert age to years, round down
age_in_years = (cardio_data["age"]/365).apply(np.floor)

#add column
cardio_data["Age in Years"] = age_in_years

# %%
cardio_data = cardio_data.drop("age", 1)

# %%
#cm to ft
height_in_feet = (cardio_data["height"]*.394)/12
cardio_data["height"].apply(np.floor)

#insert as new column
cardio_data["Height in Feet"] = height_in_feet

cardio_data = cardio_data.drop("height", 1)

cardio_data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'height'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-153cff13c34e> in <module>
#       1 #cm to ft
# ----> 2 height_in_feet = (cardio_data["height"]*.394)/12
#       3 cardio_data["height"].apply(np.floor)
#       4
#       5 #insert as new column
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'height'

# %%
gender_id = cardio_data["gender"].map({1:"Male", 2:"Female"})
cardio_data["Gender ID"] = gender_id


cardio_data
# Out:
#           id  gender  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0          0       2    110     80            1     1      0     0
# 1          1       1    140     90            3     1      0     0
# 2          2       1    130     70            3     1      0     0
# 3          3       2    150    100            1     1      0     0
# 4          4       1    100     60            1     1      0     0
# ...      ...     ...    ...    ...          ...   ...    ...   ...
# 69995  99993       2    120     80            1     1      1     0
# 69996  99995       1    140     90            2     2      0     0
# 69997  99996       2    180     90            3     1      0     1
# 69998  99998       1    135     80            1     2      0     0
# 69999  99999       1    120     80            2     1      0     0
#
#            active  cardio  Age in Years  Height in Feet Gender ID  \
# 0          Active       0          50.0        5.516000    Female
# 1          Active       1          55.0        5.122000      Male
# 2      Not Active       1          51.0        5.417500      Male
# 3          Active       1          48.0        5.548833    Female
# 4      Not Active       0          47.0        5.122000      Male
# ...           ...     ...           ...             ...       ...
# 69995      Active       0          52.0        5.516000    Female
# 69996      Active       1          61.0        5.187667      Male
# 69997  Not Active       1          52.0        6.008500    Female
# 69998  Not Active       1          61.0        5.351833      Male
# 69999      Active       0          56.0        5.581667      Male
#
#        Weight in lbs
# 0              136.0
# 1              187.0
# 2              141.0
# 3              180.0
# 4              123.0
# ...              ...
# 69995          167.0
# 69996          277.0
# 69997          231.0
# 69998          158.0
# 69999          158.0
#
# [70000 rows x 14 columns]

# %%
weight_in_lbs = (cardio_data["weight"]*2.205).apply(np.floor)
cardio_data["Weight in lbs"] = weight_in_lbs

#insert as new column
cardio_data["Weight in lbs"] = weight_in_lbs

cardio_data = cardio_data.drop("weight", 1)

cardio_data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'weight'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-8373b657ba40> in <module>
# ----> 1 weight_in_lbs = (cardio_data["weight"]*2.205).apply(np.floor)
#       2 cardio_data["Weight in lbs"] = weight_in_lbs
#       3
#       4 #insert as new column
#       5 cardio_data["Weight in lbs"] = weight_in_lbs
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'weight'

# %%
Age = [0, 36, 41, 46, 51, 56, 61, 66, 70, 76]
labels = ["0-35", "36-40", "41-45", "46-50", "51-55", "56-60", "61-65", "66-70", "75+"]
pd.cut(cardio_data["Age in Years"], Age, labels = labels).head()
# Out:
# 0    46-50
# 1    51-55
# 2    46-50
# 3    46-50
# 4    46-50
# Name: Age in Years, dtype: category
# Categories (9, object): [0-35 < 36-40 < 41-45 < 46-50 ... 56-60 < 61-65 < 66-70 < 75+]

# %%
# Active?

cardio_data['active'] = cardio_data['active'].replace(0, "Not Active")
cardio_data['active'] = cardio_data['active'].replace(1, "Active")


cardio_data
# Out:
#           id  gender  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0          0       2    110     80            1     1      0     0
# 1          1       1    140     90            3     1      0     0
# 2          2       1    130     70            3     1      0     0
# 3          3       2    150    100            1     1      0     0
# 4          4       1    100     60            1     1      0     0
# ...      ...     ...    ...    ...          ...   ...    ...   ...
# 69995  99993       2    120     80            1     1      1     0
# 69996  99995       1    140     90            2     2      0     0
# 69997  99996       2    180     90            3     1      0     1
# 69998  99998       1    135     80            1     2      0     0
# 69999  99999       1    120     80            2     1      0     0
#
#            active  cardio  Age in Years  Height in Feet Gender ID  \
# 0          Active       0          50.0        5.516000    Female
# 1          Active       1          55.0        5.122000      Male
# 2      Not Active       1          51.0        5.417500      Male
# 3          Active       1          48.0        5.548833    Female
# 4      Not Active       0          47.0        5.122000      Male
# ...           ...     ...           ...             ...       ...
# 69995      Active       0          52.0        5.516000    Female
# 69996      Active       1          61.0        5.187667      Male
# 69997  Not Active       1          52.0        6.008500    Female
# 69998  Not Active       1          61.0        5.351833      Male
# 69999      Active       0          56.0        5.581667      Male
#
#        Weight in lbs
# 0              136.0
# 1              187.0
# 2              141.0
# 3              180.0
# 4              123.0
# ...              ...
# 69995          167.0
# 69996          277.0
# 69997          231.0
# 69998          158.0
# 69999          158.0
#
# [70000 rows x 14 columns]

# %%
active = cardio_data ["active"].value_counts()

active
# Out:
# Active        56261
# Not Active    13739
# Name: active, dtype: int64

# %%
active_graph = cardio_data.groupby(["active", "cardio"]).count()["id"]
df = pd.DataFrame(active.reset_index())
df

df=df.set_index("active")
df

no_cardio_df= df.loc[df ["cardio"] == 0 ]
no_cardio_df

cardio_df= df.loc[df ["cardio"] == 1 ]
cardio_df

combined_df= pd.DataFrame({
     "cardio": cardio_df["id"],
     "no cardio": no_cardio_df ["id"]
  })

combined_df.plot.bar()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cardio'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-885bb9b6fec4> in <module>
#       6 df
#       7
# ----> 8 no_cardio_df= df.loc[df ["cardio"] == 0 ]
#       9 no_cardio_df
#      10
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cardio'
